# %%
import pandas as pd

# %%
df = pd.read_csv('UCI_Credit_Card.csv')

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
female = df[df['SEX'] == 2]
female_and_h_ed = female[female['EDUCATION'] == 2]
female_and_h_ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8656 entries, 0 to 29180
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          8656 non-null   int64
#  1   LIMIT_BAL                   8656 non-null   float64
#  2   SEX                         8656 non-null   int64
#  3   EDUCATION                   8656 non-null   int64
#  4   MARRIAGE                    8656 non-null   int64
#  5   AGE                         8656 non-null   int64
#  6   PAY_0                       8656 non-null   int64
#  7   PAY_2                       8656 non-null   int64
#  8   PAY_3                       8656 non-null   int64
#  9   PAY_4                       8656 non-null   int64
#  10  PAY_5                       8656 non-null   int64
#  11  PAY_6                       8656 non-null   int64
#  12  BILL_AMT1                   8656 non-null   float64
# ...

# %%
len(female_and_h_ed)
# Out:
# 8656

# %%
female_and_h_ed.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 7   8   100000.0    2          2         2   23      0     -1     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 7  ...      221.0     -159.0      567.0     380.0     601.0       0.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
f_and_h_ed_g = female_and_h_ed.groupby(["default.payment.next.month"])
f_and_h_ed_g['PAY_0'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    1
# Name: PAY_0, dtype: int64

# %%
f_and_h_ed_g['PAY_2'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    0
# Name: PAY_2, dtype: int64

# %%
f_and_h_ed_g['PAY_3'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    0
# Name: PAY_3, dtype: int64

# %%
f_and_h_ed_g['PAY_4'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    0
# Name: PAY_4, dtype: int64

# %%
f_and_h_ed_g['PAY_5'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    0
# Name: PAY_5, dtype: int64

# %%
f_and_h_ed_g['PAY_6'].median()
# Out:
# default.payment.next.month
# 0    0
# 1    0
# Name: PAY_6, dtype: int64

# %%
f_and_h_ed_g['BILL_AMT1'].median()
# Out:
# default.payment.next.month
# 0    27170.5
# 1    25946.5
# Name: BILL_AMT1, dtype: float64

# %%
f_and_h_ed_g['BILL_AMT2'].median()
# Out:
# default.payment.next.month
# 0    26629.0
# 1    25706.0
# Name: BILL_AMT2, dtype: float64

# %%
f_and_h_ed_g['BILL_AMT3'].median()
# Out:
# default.payment.next.month
# 0    25131.0
# 1    23833.5
# Name: BILL_AMT3, dtype: float64

# %%
f_and_h_ed_g['BILL_AMT4'].median()
# Out:
# default.payment.next.month
# 0    22444.5
# 1    21719.5
# Name: BILL_AMT4, dtype: float64

# %%
f_and_h_ed_g['BILL_AMT5'].median()
# Out:
# default.payment.next.month
# 0    20212.0
# 1    20090.5
# Name: BILL_AMT5, dtype: float64

# %%
f_and_h_ed_g['BILL_AMT6'].median()
# Out:
# default.payment.next.month
# 0    19572.0
# 1    19626.5
# Name: BILL_AMT6, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT1'].median()
# Out:
# default.payment.next.month
# 0    2371.5
# 1    1700.0
# Name: PAY_AMT1, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT2'].median()
# Out:
# default.payment.next.month
# 0    2200.0
# 1    1600.0
# Name: PAY_AMT2, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT3'].median()
# Out:
# default.payment.next.month
# 0    2000.0
# 1    1400.0
# Name: PAY_AMT3, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT4'].median()
# Out:
# default.payment.next.month
# 0    1900.0
# 1    1000.0
# Name: PAY_AMT4, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT5'].median()
# Out:
# default.payment.next.month
# 0    2000.0
# 1    1062.0
# Name: PAY_AMT5, dtype: float64

# %%
f_and_h_ed_g['PAY_AMT6'].median()
# Out:
# default.payment.next.month
# 0    1871.0
# 1    1094.5
# Name: PAY_AMT6, dtype: float64

# %%
df.pivot_table(columns=['SEX'], index=['EDUCATION', 'MARRIAGE'], aggfunc='mean')
# Out:
#                           AGE                 BILL_AMT1                 \
# SEX                         1          2              1              2
# EDUCATION MARRIAGE
# 0         1         41.000000  37.500000   11612.500000   22374.500000
#           2         36.500000  42.000000   11051.666667    7662.250000
# 1         0         37.000000  36.333333     298.000000    3148.666667
#           1         42.423077  38.870571   60196.886391   44337.774114
#           2         31.704899  30.158046   54064.399164   43004.106082
#           3         44.533333  38.150000   64661.733333   55192.750000
# 2         0         38.000000  35.800000     176.000000   31881.400000
#           1         40.332489  37.527504   56465.218143   54135.562835
#           2         31.584354  30.405637   50926.275850   53866.076961
#           3         40.698413  40.868687   35491.222222   43196.595960
# 3         0         38.000000  38.218750   26227.916667   19299.093750
# ...

# %%
def new_column(row):
    if row['LIMIT_BAL'] <= 10000:
        return 'A';
    elif row['LIMIT_BAL'] <= 100000 and row['LIMIT_BAL'] > 10000:
        return 'B';
    elif row['LIMIT_BAL'] <= 200000 and row['LIMIT_BAL'] > 100000:
        return 'C';
    elif row['LIMIT_BAL'] <= 400000 and row['LIMIT_BAL'] > 200000:
        return 'D';
    elif row['LIMIT_BAL'] <= 700000 and row['LIMIT_BAL'] > 400000:
        return 'E';
    elif row['LIMIT_BAL'] > 700000:
        return 'F';
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(df['LIMIT_BAL'])
# Out:
# (array([1.2498e+04, 7.8800e+03, 5.0590e+03, 2.7590e+03, 1.5980e+03,
#         1.2700e+02, 5.6000e+01, 2.2000e+01, 0.0000e+00, 1.0000e+00]),
#  array([  10000.,  109000.,  208000.,  307000.,  406000.,  505000.,
#          604000.,  703000.,  802000.,  901000., 1000000.]),
#  <a list of 10 Patch objects>)
